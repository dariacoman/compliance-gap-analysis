# %% [markdown]
# # UI-02 — Compliance Gap Analysis (Jupyter)
#
# NewsReader-style chat loop. Type queries; results print inline. Type `exit` to quit the loop.
#
# The full chain runs cold the first time (~110s for an uncached query against Groq Llama 70B). Subsequent runs of the same query hit the disk cache (`llm_cache/cache.json`) and complete sub-second.
#
# All chain logic lives in `src.ui.notebook_chat`; this notebook is a thin shell over the testable Python module.
#
# Reference: `compliance-gap-analysis-spec.md` § UI-02.

# %%
# %load_ext autoreload
# %autoreload 2

from src.ui.notebook_chat import chat

# %%
chat()
