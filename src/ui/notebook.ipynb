# %% [markdown]
# # UI-02 — Jupyter notebook fallback
#
# Stub. Implement during UI-02 build.
#
# Wraps the same chain logic as `streamlit_app.py` (UI-01) in a simpler interface, following the tutorial week-7 `NewsReader.chat()` loop pattern — query in / register out / loop until exit. Same logic as UI-01; rendering is plain Python printing with a tabular formatting helper.
#
# Brief-acceptable demo surface if UI-01 destabilises late in build.
#
# Reference: compliance-gap-analysis-spec.md § UI-02.
